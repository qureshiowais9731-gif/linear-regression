# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1db643e6-783c-41e2-a0ac-be588280e253" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1db643e6-783c-41e2-a0ac-be588280e253">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Out:
# Dataset loaded successfully. Shape: (545, 13)
#
# ...
#                   SIMPLE LINEAR REGRESSION (SLR)
#                   Features: Area (sq ft) -> Price
# ...
# SLR Train/Test Split: Training on 381 samples.
#
# SLR Evaluation Metrics (Test Set):
#   Mean Absolute Error (MAE): $1,387,227.90
#   Mean Squared Error (MSE): $3,193,989,923,757.62
#   R-squared (R²): 0.2583
#
# SLR Model Interpretation:
#   Equation: Price = 2,457,461.53 + 449.45 * Area
#   Coefficient (Area): $449.45
#   Interpretation: For every 1 sq ft increase in area, the price is estimated to increase by $449.45, assuming a linear relationship.
# ...
#                  MULTIPLE LINEAR REGRESSION (MLR)
#           Features: Area, Bedrooms, Bathrooms, and Categorical
# ...
# MLR Train/Test Split: Training on 381 samples with 13 features.
#
# MLR Evaluation Metrics (Test Set):
#   Mean Absolute Error (MAE): $920,392.94
#   Mean Squared Error (MSE): $1,523,019,469,501.29
#   R-squared (R²): 0.6463
#
# MLR Model Interpretation:
# ...
